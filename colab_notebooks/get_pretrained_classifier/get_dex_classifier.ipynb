# %%
# ╔══════════════════════════════════════════════════════════════════════╗
#   Script — Download and persist the FFHQ‑LS age‑classifier
# ╚══════════════════════════════════════════════════════════════════════╝
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
MODEL_DIR_DRIVE = "/content/drive/MyDrive/trained_models"
MODEL_NAME      = "dex_imdb_wiki.caffemodel.pt"
MODEL_PATH      = f"{MODEL_DIR_DRIVE}/{MODEL_NAME}"

# %%
import os
os.makedirs(MODEL_DIR_DRIVE, exist_ok=True)

# %%
if not os.path.exists(MODEL_PATH):
    # !pip install -q gdown
    FILE_ID = "1a0jghZx44uC_kIIvD-UEcNp4Xz8Bpso1"     # ← insert the real ID
    # !gdown --id $FILE_ID -O $MODEL_PATH
    print(f"Downloaded classifier to {MODEL_PATH}")
else:
    print(f"Classifier already exists at {MODEL_PATH}")
# Out:
# /usr/local/lib/python3.11/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1a0jghZx44uC_kIIvD-UEcNp4Xz8Bpso1
# From (redirected): https://drive.google.com/uc?id=1a0jghZx44uC_kIIvD-UEcNp4Xz8Bpso1&confirm=t&uuid=c119be9c-57ec-4fc0-939c-57289f6ef79b
# To: /content/drive/MyDrive/trained_models/dex_imdb_wiki.caffemodel.pt
# 100% 539M/539M [00:06<00:00, 78.8MB/s]
# Downloaded classifier to /content/drive/MyDrive/trained_models/dex_imdb_wiki.caffemodel.pt
