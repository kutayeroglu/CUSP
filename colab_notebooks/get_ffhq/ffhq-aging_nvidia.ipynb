# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
DATA_ROOT='/content/drive/MyDrive/datasets/ffhq_aging'   # persistent
# !mkdir -p $DATA_ROOT
# %cd $DATA_ROOT
# Out:
# /content/drive/MyDrive/datasets/ffhq_aging

# %%
# !git clone https://github.com/royorel/FFHQ-Aging-Dataset.git
# %cd FFHQ-Aging-Dataset
# Out:
# /content/drive/MyDrive/datasets/ffhq_aging/FFHQ-Aging-Dataset

# %%
# !pip install -r requirements.txt

# %%
# FFHQ license should be ~1600 bytes
# !wc -c *LICENSE*.txt
# Out:
# 1610 LICENSE.txt

# %%
# !python download_ffhq_aging.py --pydrive --cmd_auth --resolution 256
# Out:
# Go to the following link in your browser:
#
#     https://accounts.google.com/o/oauth2/auth?client_id=238669659915-kd812orfmgb8np0fsb6gq0aseihahm8u.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&access_type=offline&response_type=code
#
# Enter verification code: 4/1Ab_5qllnFzEcgaeN6heyU1IsTx1hhz5epgxzVm0Otq2qDc_hsvYc5tcQdNk
# Authentication successful.
# authorized access to google drive API!
# Parsing JSON metadata...
# ...
# - done processing 7/70001 filesTraceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/pydrive/files.py", line 237, in FetchMetadata
#     .execute(http=self.http)
#      ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/googleapiclient/_helpers.py", line 130, in positional_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
# Should list one shortcut named “ffhq-dataset”
drive="$(gcloud auth list --format='value(account)')"
drive_link="https://drive.google.com/drive/folders/1u2xu7bSrWxrbUxk-dT-UvEJq8IjdmNTP"
# !echo "Open $drive_link in your browser – it should show “Shortcut in My Drive”."
# Out:
# Open https://drive.google.com/drive/folders/1u2xu7bSrWxrbUxk-dT-UvEJq8IjdmNTP in your browser – it should show “Shortcut in My Drive”.
