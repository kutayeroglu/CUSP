# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# ---- paths --------------------------------------------------------------
CLASSIFIER_PATH = "/content/drive/MyDrive/trained_models/resnet_ffhq_ls.pt"
DEX_CLASSIFIER_PATH = "/content/drive/MyDrive/trained_models/dex_imdb_wiki.caffemodel.pt"
CSV_PATH        = "/content/drive/MyDrive/datasets/FFHQaging_LS/FFHQaging.csv"
IMG_DIR         = "/content/drive/MyDrive/datasets/FFHQaging_LS/images"
REPO_DIR        = "/content/CUSP"

# %%
###########################
## Sanity check for data ##
###########################

# import os, glob, textwrap, subprocess, sys, pathlib

# DATA_DIR = "/content/drive/MyDrive/datasets/FFHQaging_LS/images"

# print("DATA_DIR           :", DATA_DIR)
# print("Exists on disk?    :", os.path.isdir(DATA_DIR))
# print("# *.png files found:", len(glob.glob(os.path.join(DATA_DIR, "*.png"))))
# print("# *.jpg files found:", len(glob.glob(os.path.join(DATA_DIR, "*.jpg"))))

# # peek at a couple of names
# for f in sorted(glob.glob(os.path.join(DATA_DIR, "*"))[:5]):
#     print(" ", os.path.basename(f))

# %%
# !git clone https://github.com/kutayeroglu/CUSP.git $REPO_DIR
# %cd /content/CUSP
# Out:
# fatal: destination path '/content/CUSP' already exists and is not an empty directory.

# %%
# !cp -f "$DEX_CLASSIFIER_PATH" dex_imdb_wiki.caffemodel.pt
# !ls -l dex_imdb_wiki.caffemodel.pt # Verify that file's in place

# %%
# !pip install -q torch torchvision pillow click tqdm tensorboard==2.12 opencv-python-headless
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 48.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 113.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 91.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 51.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 11.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 41.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 19.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 103.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.3/781.3 kB 52.5 MB/s eta 0:00:00
# ...

# %%
# !python train.py \
        --csv  {CSV_PATH} \
        --data {IMG_DIR} \
        --classifier_path {CLASSIFIER_PATH} \
        --outdir ./training-runs-ffhqls \
        --gpus 0 --cfg 256 --dataset ffhq_lat \
        --downsamples 5 --bias False --class_w 0.1 \
        --skip_layers 2 --skip_kind linear --act_reg l2 \
        --skip_grad_blur gb --blur_skip true --blur_msk random \
        --mixing_prob 0.0 --disc_class true --fake_rec false \
        --cycle_w 10 --cmap_kind number
# Out:
# Training options:
# {
#   "gb": "Fixed",
#   "msk": "Reversed",
#   "num_gpus": 1,
#   "gpu_list": [
#     "0"
#   ],
#   "image_snapshot_ticks": 1,
#   "network_snapshot_ticks": 20,
#   "random_seed": 0,
#   "training_set_kwargs": {
#     "class_name": "training.dataset.ImageCSVDataset",
#     "csv_path": "/content/drive/MyDrive/datasets/FFHQaging_LS/FFHQaging.csv",
#     "image_path": "/content/drive/MyDrive/datasets/FFHQaging_LS/images",
#     "is_train": true,
#     "cmap_pre_kind": "number",
#     "transforms": "ffhq_lat",
#     "resolution": 256,
#     "use_labels": true,
#     "max_size": 60000
#   },
#   "test_set_kwargs": {
#     "class_name": "training.dataset.ImageCSVDataset",
#     "csv_path": "/content/drive/MyDrive/datasets/FFHQaging_LS/FFHQaging.csv",
#     "image_path": "/content/drive/MyDrive/datasets/FFHQaging_LS/images",
#     "is_train": false,
#     "cmap_pre_kind": "number",
#     "transforms": "ffhq_lat"
#   },
#   "data_loader_kwargs": {
# ...

# %%
# !grep -R --line-number "dex_imdb_wiki.caffemodel.pt" training | head -n 20

# %%
# !grep -R --line-number "classifier_kwargs" training | head -n 20
# Out:
# grep: training/__pycache__/networks.cpython-311.pyc: binary file matches
# training/networks.py:1319:    def __init__(self, classifier_kwargs, map_type="gb"):
# training/networks.py:1321:        self.model = dnnlib.util.construct_class_by_name(**classifier_kwargs)
# training/networks.py:1448:        classifier_kwargs={},
# training/networks.py:1555:                    classifier_kwargs, map_type=skip_grad_blur
# training/networks.py:1596:                    classifier_kwargs, map_type="cam"
# training/loss.py:525:                 classifier_kwargs, classification_loss_kwargs, random_class_kwargs,
# training/loss.py:537:        self.classifier = dnnlib.util.construct_class_by_name(**classifier_kwargs).to(device)
# grep: training/__pycache__/loss.cpython-311.pyc: binary file matches
